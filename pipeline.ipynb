# %%
from langchain.llms import OpenAI
import config
import os
from pathlib import Path
from typing import List

from dotenv import load_dotenv

load_dotenv(f"{parent_path}/.env")


openai_api_key = os.environ["OPENAI_API_KEY"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/vatche/.work/langchain/pipeline.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from typing import List
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from dotenv import load_dotenv
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> parent_path = Path(__file__).parent.absolute()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> load_dotenv(f"{parent_path}/.env")
# ...

# %%
openai_api_key = config.OPENAI_API_KEY
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/vatche/.work/langchain/pipeline.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> openai_api_key = config.OPENAI_API_KEY
#
# AttributeError: module 'config' has no attribute 'OPENAI_API_KEY'

# %%
llm = OpenAI(temperature=0.9)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /home/vatche/.work/langchain/pipeline.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> llm = OpenAI(temperature=0.9)
#
# File ~/.work/langchain/.venv/lib/python3.10/site-packages/langchain/load/serializable.py:97, in Serializable.__init__(self, **kwargs)
#      96 def __init__(self, **kwargs: Any) -> None:
# ---> 97     super().__init__(**kwargs)
#      98     self._lc_kwargs = kwargs
#
# File ~/.work/langchain/.venv/lib/python3.10/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
# ...

# %%
text = "hello"
llm(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/vatche/.work/langchain/pipeline.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> text = "hello"
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vatche/.work/langchain/pipeline.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> llm(text)
#
# TypeError: 'module' object is not callable

# %%
job_listings = []

# Extract job listings
for job_item in soup.find_all("li", class_="result-card"):
    job_title = job_item.find("a", class_="result-card__full-card-link").text.strip()
    company_name = job_item.find("a", class_="result-card__subtitle-link").text.strip()
    location = job_item.find("span", class_="job-result-card__location").text.strip()

    has_easy_apply = "Easy Apply" in job_item.text
    actively_recruiting = "Actively recruiting" in job_item.text

    job_listings.append(
        {
            "Job Title": job_title,
            "Company Name": company_name,
            "Location": location,
            "Has Easy Apply": has_easy_apply,
            "Actively Recruiting": actively_recruiting,
        }
    )

# Create a DataFrame
df = pd.DataFrame(job_listings)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
r = requests.get("https://www.linkedin.com/jobs/collections/recommended/?currentJobId=3695798504",

# %%
r.content
# Out:
# b'<!DOCTYPE html><html lang="en" class="theme theme--mercado "><head>\n    <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>\n\n    <title>LinkedIn</title>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="asset-url" class="mercado-icons-sprite" id="artdeco-icons/static/images/sprite-asset" content="https://static.licdn.com/aero-v1/sc/h/2r5xcgd2sa4ezr5gbzlkasp5d">\n    <meta name="description" content="">\n    <meta name="google" content="notranslate">\n    <meta name="service" content="voyager-web">\n    <meta name="theme-color" content="#ffffff" id="theme-color-meta-tag">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <meta name="baseCDNUrl" content="htt
# ...

# %%
keyword = "python developer"
location = "remote"
job_listings = scrape_indeed_jobs(keyword, location)

for job in job_listings:
    print(job)
